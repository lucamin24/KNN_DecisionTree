# %% [markdown]
# <a href="https://colab.research.google.com/github/lucamin24/KNN_DecisionTree/blob/main/IronHack_KNNvsDecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importando biblbiotecas

# %%
import pandas as pd
import seaborn as sns

# %%
penguins_df= sns.load_dataset ('penguins')
print (penguins_df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_df= penguins_df.dropna()
print (penguins_df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Parametros do modelo

# %%
X= penguins_df[[ "bill_length_mm", "bill_depth_mm", "flipper_length_mm"] ]
y= penguins_df[[ "body_mass_g"] ]

# %% [markdown]
# Criando o modelo

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X,y)
from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor(n_neighbors =3)
knn.fit (X_train, y_train)
random_penguin = X_test.sample ()
random_penguin
knn.predict (random_penguin)
# Out:
# array([[4816.66666667]])

# %% [markdown]
# Preparando o modelo para uma Decisão Tree para determinar se um pinguin é Macho ou Femea

# %%
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_df ["sex"]=penguins_df["sex"].apply (lambda x: 1 if "female" else 0)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    1
# 1         3800.0    1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier (max_depth =3)
tree_model.fit (X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
random_penguin2= X_test.sample ()
random_penguin2
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm
# 263            49.6           15.0              216.0

# %%
tree_model.predict (random_penguin2)
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

fig,axes = plt.subplots (nrows =1, ncols=1, figsize= (34,20))

plot_tree(tree_model, filled= True, rounded=True, feature_names=list (X.columns))
plt.show ()
